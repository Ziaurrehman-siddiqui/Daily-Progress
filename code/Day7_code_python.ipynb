# %%
with open("profile.jpg", "rb") as file:
  data = file.read()
  print(data)
# Out:
# b'c:\\Users\\Zia Siddiqui\\Downloads\\profile.jpg'

# %%
with open("new_image.jpg", "wb") as file:
file.write(data)
# Out:
#   Cell In[8], line 2
#     file.write(data)
#     ^
# IndentationError: expected an indented block after 'with' statement on line 1

# %%
with open("profile.jpg", "wb") as file:
 file.write(data)
