# %%
#Task 1: Simple Bill Calculator

#User se input lo:

#item_name (string)

#price (float)

#quantity (int)

#Output:

#total = price * quantity

#print in f-string format

item_name=input("Enter item name")
price_item=float(input("Enter item price"))
quantity_item=int(input("Enter the quantity of item"))

total_bill= price_item*quantity_item

print(f"Name:{item_name},Price:{price_item},Quantity:{quantity_item} and Bill:{total_bill}")

# %%
username=input("Enter your name:")
username=username.strip()
username=username.lower()
temp=username.replace("_","")
if temp.isalnum():
    print("user name is valid")
else:
    print("User name is invalid")
# Out:
# Enter your name: Ziaur_123
# user name is valid

# %%
sentence=input("Enter a sentence")
words=sentence.split()
words_count=len(words)
remove_space=sentence.replace(" ","")
total_characters=len(remove_space)
starts_with_hi=sentence.lower().startswith("hi")

print("total_words:",words_count)
print("Total Characters:",total_characters)
print("Sentence starts with hi:",starts_with_hi)
# Out:
# Enter a sentence I am Ziaur Rehman. Nice to meet you!
# total_words: 8
# Total Characters: 29
# Sentence starts with hi: False

# %%
Correct_User_Name="ZIAUR REHMAN SIDDIQUI"
Correct_Password="Ziaur123"
User_Name=input("Enter username")
User_Password=inpur("Enter your password")
if(Correct_User_Name==User_Name && Correct_Password==User_Password):
  print("Login Successfully")
else:
    print("Inva
# Out:
# Enter username ZIAUR REHMAN SIDDIQUI
# Enter your password Ziaur123
# Login Successfully

# %%
c
# Out:
# Guess a number 8
# Too High
# Attempts left: 2
# Guess a number 5
# TOO LOW
# Attempts left: 1
# Guess a number 9
# Too High
# Attempts left: 0
# Game is over,Secret Number was: 7

# %%
import random

secret = random.randint(1,10)
attempts = 3

while attempts > 0:
    guess = int(input("Guess the number (1 to 10): "))

    if guess == secret:
        print(" You Win! Correct guess.")
        break
    elif guess > secret:
        print(" Hint: Too High ")
    else:
        print(" Hint: Too Low ")

    attempts -= 1
    print("Attempts left:", attempts)

if attempts == 0:
    print(" Game Over! The secret number was", secret)
# Out:
# Guess the number (1 to 10):  4
#  Hint: Too High
# Attempts left: 2
# Guess the number (1 to 10):  7
#  Hint: Too High
# Attempts left: 1
# Guess the number (1 to 10):  5
#  Hint: Too High
# Attempts left: 0
#  Game Over! The secret number was 1
