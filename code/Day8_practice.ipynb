# %%
#json.dumps() – Convert Python object to JSON string
import json
data = {"name": "Zia", "age": 20, "city": "New Delhi"}
json_variable = json.dumps(data)
print(json_variable) 
print(type(json_variable))
# Out:
# {"name": "Zia", "age": 20, "city": "New Delhi"}
# <class 'str'>

# %%
#json.loads() – Convert JSON string to Python object
json_data = '{"name": "Zia", "age": 20, "city": "New Delhi"}'
python_obj = json.loads(json_data)
print(python_obj) 
print(type(python_obj))
# Out:
# {'name': 'Zia', 'age': 20, 'city': 'New Delhi'}
# <class 'dict'>

# %%
'''Summary of Common JSON Methods
Method
Description
json.dumps(obj)
json.dump(obj, file)
Converts Python
object to JSON
string
Example
json.dumps(data)
Writes JSON to a
file
json.dump(data, file)
json.loads(json_string)
json.load(file)
Converts JSON
string to Python
object
json.loads(json_data)
Reads JSON from
a file
Object Oriented Programming in Python
Concept
json.load(file)'''
# Out:
# 'Summary of Common JSON Methods\nMethod\nDescription\njson.dumps(obj)\njson.dump(obj, file)\nConverts Python\nobject to JSON\nstring\nExample\njson.dumps(data)\nWrites JSON to a\nfile\njson.dump(data, file)\njson.loads(json_string)\njson.load(file)\nConverts JSON\nstring to Python\nobject\njson.loads(json_data)\nReads JSON from\na file\nObject Oriented Programming in Python\nConcept\njson.load(file)'
