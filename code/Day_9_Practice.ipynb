# %%
class Laptop:
  def __init__(self, brand, model):
        self.brand = brand  
# Attribute
        self.model = model  
# Attribute
  def display_info(self): # Method
   return f"{self.brand} {self.model}"
# Creating an Object (Instance)
  car1 = Car("Toyota", "Camry")
  print(car1.display_info())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 class Laptop:
#       2   def __init__(self, brand, model):
#       3         self.brand = brand
#
# Cell In[3], line 10, in Laptop()
#       8    return f"{self.brand} {self.model}"
#       9 # Creating an Object (Instance)
# ---> 10   car1 = Car("Toyota", "Camry")
#      11   print(car1.display_info())
#
# NameError: name 'Car' is not defined

# %%
class Car:
 def __init__(self, brand, model):
        self.brand = brand  
# Attribute
        self.model = model  
# Attribute
def display_info(self): # Method
 return f"{self.brand} {self.model}"
# Creating an Object (Instance)
car1 = Car("Toyota", "Camry")
print(car1.display_info())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 11
#       9 # Creating an Object (Instance)
#      10 car1 = Car("Toyota", "Camry")
# ---> 11 print(car1.display_info())
#
# AttributeError: 'Car' object has no attribute 'display_info'

# %%
class Car:
    def __init__(self, brand, model):   # Constructor
        self.brand = brand              # Attribute
        self.model = model              # Attribute

    def display_info(self):             # Method
        return f"{self.brand} {self.model}"

# Creating an Object (Instance)
car1 = Car("Toyota", "Camry")
print(car1.display_info())
# Out:
# Toyota Camry

# %%
class BankAccount:
  def __init__(self, balance):
        self.__balance = balance  # Private Attribute
  def get_balance(self): # Getter
   return self.__balance
  def deposit(self, amount): # Setter
   if amount > 0:
            self.__balance += amount
# Using Encapsulation
account = BankAccount(1000)
account.deposit(500)
print(account.get_balance())
# Out:
# 1500
